# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
indep
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
dep=dataset[['charges']]

# %%
dep
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
 from sklearn.model_selection import GridSearchCV
 from sklearn.ensemble import RandomForestRegressor
 param_grid = {'criterion':['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
                 'max_features': ['auto','sqrt','log2'],
                 'n_estimators':[10,100]}


grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1)

# fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 28 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.82352975 0.83307698 0.81733418 0.83190488
#         nan        nan 0.81794374 0.83590777 0.82012077 0.83295298
#         nan        nan 0.82351866 0.83561283 0.81216249 0.83288681
#         nan        nan 0.81860648 0.83322195 0.81630536 0.83305207]
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)

re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.003211      0.002070         0.000000        0.000000
# 1        0.002422      0.001837         0.000000        0.000000
# 2        0.072939      0.014637         0.012836        0.008679
# 3        0.465393      0.029413         0.025690        0.006825
# 4        0.064816      0.006839         0.011192        0.004724
# 5        0.476518      0.023736         0.027610        0.004390
# 6        0.002950      0.002099         0.000000        0.000000
# 7        0.003636      0.002261         0.000000        0.000000
# 8        0.166169      0.001804         0.001890        0.003779
# 9        1.707540      0.303125         0.027297        0.007544
# 10       0.151571      0.008214         0.002002        0.004004
# 11       2.400622      0.462498         0.041769        0.013351
# 12       0.003776      0.004331         0.000000        0.000000
# 13       0.001794      0.001745         0.000000        0.000000
# 14       0.093715      0.006920         0.010680        0.009039
# 15       0.768449      0.016345         0.035026        0.004616
# 16       0.089513      0.006227         0.008899        0.002172
# 17       1.204459      0.192027         0.059974        0.028589
# 18       0.004497      0.002702         0.000000        0.000000
# 19       0.002730      0.002591         0.000000        0.000000
# 20       0.303017      0.051320         0.026260        0.016894
# 21       1.545356      0.042817         0.066760        0.030042
# 22       0.226661      0.050888         0.013722        0.003857
# 23       1.248419      0.227494         0.028456        0.009591
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               auto                  10
# 1    squared_error               auto                 100
# 2    squared_error               sqrt                  10
# 3    squared_error               sqrt                 100
# 4    squared_error               log2                  10
# 5    squared_error               log2                 100
# 6   absolute_error               auto                  10
# 7   absolute_error               auto                 100
# 8   absolute_error               sqrt                  10
# 9   absolute_error               sqrt                 100
# 10  absolute_error               log2                  10
# 11  absolute_error               log2                 100
# 12    friedman_mse               auto                  10
# 13    friedman_mse               auto                 100
# 14    friedman_mse               sqrt                  10
# 15    friedman_mse               sqrt                 100
# 16    friedman_mse               log2                  10
# 17    friedman_mse               log2                 100
# 18         poisson               auto                  10
# 19         poisson               auto                 100
# 20         poisson               sqrt                  10
# 21         poisson               sqrt                 100
# 22         poisson               log2                  10
# 23         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.845842
# 3   {'criterion': 'squared_error', 'max_features':...           0.857510
# 4   {'criterion': 'squared_error', 'max_features':...           0.840985
# 5   {'criterion': 'squared_error', 'max_features':...           0.853402
# 6   {'criterion': 'absolute_error', 'max_features'...                NaN
# 7   {'criterion': 'absolute_error', 'max_features'...                NaN
# 8   {'criterion': 'absolute_error', 'max_features'...           0.847830
# 9   {'criterion': 'absolute_error', 'max_features'...           0.858970
# 10  {'criterion': 'absolute_error', 'max_features'...           0.848532
# 11  {'criterion': 'absolute_error', 'max_features'...           0.855401
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.860138
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.859023
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.850214
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.854183
# 18  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.856993
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.858752
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.843668
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.861282
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.775554           0.843371           0.815221
# 3            0.776674           0.861487           0.825863
# 4            0.775512           0.835617           0.811860
# 5            0.776810           0.859279           0.828252
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.766381           0.856771           0.806019
# 9            0.785787           0.861220           0.827079
# 10           0.759956           0.834127           0.822006
# 11           0.780448           0.858236           0.827713
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.770053           0.838665           0.824243
# 15           0.780618           0.860212           0.834732
# 16           0.726258           0.846184           0.810619
# 17           0.775943           0.860237           0.831657
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.742574           0.855285           0.806587
# 21           0.779233           0.860103           0.829135
# 22           0.759030           0.840198           0.815651
# 23           0.782028           0.854910           0.829313
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2            0.837661         0.823530        0.026313                9
# 3            0.843851         0.833077        0.030833                4
# 4            0.822697         0.817334        0.023244               14
# 5            0.841783         0.831905        0.029522                8
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8            0.812717         0.817944        0.032339               13
# 9            0.846482         0.835908        0.027837                1
# 10           0.835982         0.820121        0.031236               11
# 11           0.842967         0.832953        0.028382                6
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.824494         0.823519        0.029767               10
# 15           0.843478         0.835613        0.029121                2
# 16           0.827537         0.812162        0.045219               16
# 17           0.842414         0.832887        0.030121                7
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.831593         0.818606        0.042220               12
# 21           0.838887         0.833222        0.029455                3
# 22           0.822980         0.816305        0.030479               15
# 23           0.837727         0.833052        0.027978                5

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 40
# BMI: 33
# Children: 3
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#␣!change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[39064.7858039]
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
